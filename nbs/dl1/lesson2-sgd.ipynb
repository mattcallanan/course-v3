# %%
# %matplotlib inline
from fastai.basics import *

# %% [markdown]
# In this part of the lecture we explain Stochastic Gradient Descent (SGD) which is an **optimization** method commonly used in neural networks. We will illustrate the concepts with concrete examples.

# %% [markdown]
# #  Linear Regression problem

# %% [markdown]
# The goal of linear regression is to fit a line to a set of points.

# %%
n=100

# %%
x = torch.ones(n,2) 
x[:,0].uniform_(-1.,1)
x[:10]
# Out:
# tensor([[-0.3856,  1.0000],
#         [ 0.3568,  1.0000],
#         [-0.7636,  1.0000],
#         [-0.2627,  1.0000],
#         [ 0.2831,  1.0000],
#         [ 0.2485,  1.0000],
#         [-0.4220,  1.0000],
#         [-0.0304,  1.0000],
#         [-0.0203,  1.0000],
#         [-0.6952,  1.0000]])

# %%
a = tensor(3.,2); a
# Out:
# tensor([3., 2.])

# %% [raw]
# torch.rand??

# %%
y = x@a + torch.rand(n)
b = torch.rand(n)
n
b
torch.rand??

# %%
plt.scatter(x[:,0], y);

# %% [markdown]
# You want to find **parameters** (weights) `a` such that you minimize the *error* between the points and the line `x@a`. Note that here `a` is unknown. For a regression problem the most common *error function* or *loss function* is the **mean squared error**.

# %%
def mse(y_hat, y): return ((y_hat-y)**2).mean()

# %% [markdown]
# Suppose we believe `a = (-1.0,1.0)` then we can compute `y_hat` which is our *prediction* and then compute our error.

# %%
a = tensor(-1.,1)

# %%
y_hat = x@a
mse(y_hat, y)
# Out:
# tensor(7.1180)

# %%
plt.scatter(x[:,0],y)
plt.scatter(x[:,0],y_hat);

# %% [markdown]
# So far we have specified the *model* (linear regression) and the *evaluation criteria* (or *loss function*). Now we need to handle *optimization*; that is, how do we find the best values for `a`? How do we find the best *fitting* linear regression.

# %% [markdown]
# # Gradient Descent

# %% [markdown]
# We would like to find the values of `a` that minimize `mse_loss`.
#
# **Gradient descent** is an algorithm that minimizes functions. Given a function defined by a set of parameters, gradient descent starts with an initial set of parameter values and iteratively moves toward a set of parameter values that minimize the function. This iterative minimization is achieved by taking steps in the negative direction of the function gradient.
#
# Here is gradient descent implemented in [PyTorch](http://pytorch.org/).

# %%
a = nn.Parameter(a); a
# Out:
# Parameter containing:
# tensor([-1.,  1.], requires_grad=True)

# %%
def update():
    y_hat = x@a
    loss = mse(y, y_hat)
    if t % 10 == 0: print(loss)
    loss.backward()
    with torch.no_grad():
        a.sub_(lr * a.grad)
        a.grad.zero_()

# %%
lr = 1e-1
for t in range(100): update()
# Out:
# tensor(7.1180, grad_fn=<MeanBackward1>)
# tensor(1.4747, grad_fn=<MeanBackward1>)
# tensor(0.4153, grad_fn=<MeanBackward1>)
# tensor(0.1582, grad_fn=<MeanBackward1>)
# tensor(0.0950, grad_fn=<MeanBackward1>)
# tensor(0.0794, grad_fn=<MeanBackward1>)
# tensor(0.0756, grad_fn=<MeanBackward1>)
# tensor(0.0747, grad_fn=<MeanBackward1>)
# tensor(0.0744, grad_fn=<MeanBackward1>)
# tensor(0.0744, grad_fn=<MeanBackward1>)

# %%
plt.scatter(x[:,0],y)
plt.scatter(x[:,0],x@a);

# %% [markdown]
# ## Animate it!

# %%
from matplotlib import animation, rc
rc('animation', html='jshtml')

# %%
a = nn.Parameter(tensor(-1.,1))

fig = plt.figure()
plt.scatter(x[:,0], y, c='orange')
line, = plt.plot(x[:,0], x@a)
plt.close()

def animate(i):
    update()
    line.set_ydata(x@a)
    return line,

animation.FuncAnimation(fig, animate, np.arange(0, 100), interval=20)
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imge39261d4cb724e71b8e47358783fa9ad">
#     <br>
#     <input id="_anim_slidere39261d4cb724e71b8e47358783fa9ad" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="anime39261d4cb724e71b8e47358783fa9ad.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="anime39261d4cb724e71b8e47358783fa9ad.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="anime39261d4cb724e71b8e47358783fa9ad.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="anime39261d4cb724e71b8e47358783fa9ad.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="anime39261d4cb724e71b8e47358783fa9ad.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="anime39261d4cb724e71b8e47358783fa9ad.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="anime39261d4cb724e71b8e47358783fa9ad.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="anime39261d4cb724e71b8e47358783fa9ad.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="anime39261d4cb724e71b8e47358783fa9ad.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="anime39261d4cb724e71b8e47358783fa9ad.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_selecte39261d4cb724e71b8e47358783fa9ad" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imge39261d4cb724e71b8e47358783fa9ad";
#     var slider_id = "_anim_slidere39261d4cb724e71b8e47358783fa9ad";
#     var loop_select_id = "_anim_loop_selecte39261d4cb724e71b8e47358783fa9ad";
#     var frames = new Array(0);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDIuMi4yLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvhp/UCwAAIABJREFUeJzt3X10VNW9//HPJAFa1Io8pEBQkxBA\
# SAy0hKfbWwU0IqhtqVhBruLTL9xV26pdavXnanX1mmK7+mSvDzU/rWUpQrWl8rtIsbUoa+nFG6Pg\
# T9RaCwkFpDYmPqAIhGT//hgy5OGcmTMz58yZPfN+rdWFnDlnzr6T3Pmw9/7ufSLGGCMAACxTEHYD\
# AABIBQEGALASAQYAsBIBBgCwEgEGALASAQYAsBIBBgCwEgEGALASAQYAsBIBBgCwEgEGALASAQYA\
# sBIBBgCwEgEGALASAQYAsBIBBgCwEgEGALASAQYAsBIBBgCwEgEGALASAQYAsBIBBgCwEgEGALAS\
# AQYAsBIBBgCwEgEGALASAQYAsBIBBgCwEgEGALASAQYAsBIBBgCwEgEGALASAQYAsBIBBgCwUlHY\
# DQjK8OHDVVpaGnYzAMAqLS0tevfdd8Nuhic5G2ClpaVqamoKuxkAYJWampqwm+AZQ4gAACsRYAAA\
# KxFgAAArEWAAACsRYAAAKxFgAJANmldJT5RKjxZE/2xeFXaLsl7OltEDgDWaV0mNdVLngejfD+yK\
# /l2SypaG164sRw8MAML2yq3Hwqtb54HocbgiwAAgbAf+ntxxSCLAAMB/yc5nDT4lueOQRIABgL+6\
# 57MO7JJkjs1nxQuxyfVS4eDexwoHR4/DFQEGAH5KZT6rbKk0vUEafKqkSPTP6Q3uBRxULEqiChEA\
# /JXqfFbZUm8Vh04Vi1sulVqfl6bfm1xbLUcPDAD8FPR8llMPT0b62y/zridGgAGAn4Kez3LtyZm8\
# K7snwADAT8nOZyUrXk8uz8rumQMDAL95nc9KxeT66JyXTP/X8qzsnh4YANim7xClJCkSLejIo6pE\
# emAAYIu+FYi9HO2R5dE+ivTAAMAWjhWIDvJkH0UCDABskUyRRh4UdFgzhFhaWqoTTjhBhYWFKioq\
# UlNTU9hNAoDMaF51tEflULjhJg8KOqwJMEl65plnNHz48LCbAQCZE3fey0We7KPIECIAZLO4816R\
# /ocGDvN33VkWsybAIpGIzjnnHE2dOlUNDQ1hNwcAMsN1LisizXq494LpWY9Ii97Ni/CSLBpCfO65\
# 51RSUqJ//vOfqq2t1WmnnaYzzjij1zkNDQ2xcGttbQ2jmQDyQfec1IG/R+eaJtcHFxqDTzn6aBaH\
# 40EumLaANT2wkpISSVJxcbEWLlyoxsbGfufU1dWpqalJTU1NGjFiRKabCCAfpPK8r3TwrDBXVgTY\
# xx9/rP3798f++49//KOqqqpCbhWAvJTK877SEfTeihazYgjxnXfe0cKFCyVJR44c0SWXXKJzzz03\
# 5FYByEupPu8rHXk+VOjGigArLy/XK6+8EnYzACD+nBQyyoohRADwXfOq6Ma3jxYktwEuc1JZw4oe\
# GAD4qu/i4GQ2wO1+PVNViHBFgAHIP/EKMXoGkVu5PHNSWYEAA5B/vBRipNNLQ0YwBwYgd3id13Ir\
# uOh5PNPl8kgaAQYgNySzwNhLIUYY5fJICgEGIDck02PysjjYSy8NoWIODEBuSLbHlKgQY3J9/8eY\
# UC6fVeiBAcgNfveY2MIp69EDA5AbgugxUS6f1eiBAcgN9JjyDj0wALnDa48pk8/zQmAIMAD5hQXK\
# OYMhRAD5hQXKOYMAA5B5qe4E7wfXcvtd/dsTZjuREEOIADIr3SG8dOev3J7nJanXDh6tz0vNKxlq\
# zGL0wABkVjpDeMlsF+XGaRupvjoPSDsaGGrMcgQYgMxKZ49BP+av+pbbuzGdzsfZCzFrEGAAMiud\
# HTNSCT+neayypdJXWqRLuo4GWRLYCzFrEGAAMsvLTvBukg0/L0OOk+vl3hPrc5y9E

# %% [markdown]
# In practice, we don't calculate on the whole file at once, but we use *mini-batches*.

# %% [markdown]
# ## Vocab

# %% [markdown]
# - Learning rate
# - Epoch
# - Minibatch
# - SGD
# - Model / Architecture
# - Parameters
# - Loss function
#
# For classification problems, we use *cross entropy loss*, also known as *negative log likelihood loss*. This penalizes incorrect confident predictions, and correct unconfident predictions.
